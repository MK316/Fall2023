# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/Fall2023/blob/main/GTTS1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🔈Text to Speech (TTS)
#
# Google {gTTS}

# %% [markdown]
# ## Set-up

# %%
from IPython.display import YouTubeVideo, display, Audio, Image
import pandas as pd

# %% [markdown]
# ### 🔵 gTTS setting

# %%
#@markdown 🔄 Making functions: etts('text'), ktts('text')
# %%capture
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

dialect = "us"
def etts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "en", tld = dialect,
                    slow = True)

  gtts_object.save("E-audio.mp3")
  return Audio("E-audio.mp3")

def ktts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "ko",
                    slow = False)

  gtts_object.save("K-audio.mp3")
  return Audio("K-audio.mp3")

def ftts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "fr",
                    slow = False)

  gtts_object.save("F-audio.mp3")
  return Audio("F-audio.mp3")

# %% [markdown]
# gTTS language options [visit](https://gtts.readthedocs.io/en/latest/module.html)

# %%
#@markdown Transcribe what you hear:
text = "Jane kept repeating 'belts, little roses, n crayons.'"
etts(text)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Allophonic rule practice

# %% [markdown]
# 1. Aspiration: repeat, rotation, special, history, happen
# 2. Devoicing: Add two more here.
# 3. I still remember this day and stay grateful for all the good moments we shared.
# 4. face vs. phase; cap vs. cab
# 5. pray, play, murray, cue, Tuesday
# 6. beaten, mountain, uh-uh, uh-huh
# 7. prism, chasm, little, battle, channel
# 8. pretty, daddy, many
# 9. eighth, tenth, wealth
# 10. most people, best game, grandmaster, desk job
# 11. prince vs. prints, tense vs. tents
# 12. big game, top post, straight tissue vs. straight issue
# 13. kep vs. cap; key vs. kept
# 14. life vs. file, leaf vs. feel

# %%
rules = "1. Aspiration: repeat, rotation, special, history, happen" #@param = ["1. Aspiration: repeat, rotation, special, history, happen", "2. Add two more here", "3. I still remember this day and stay grateful for all the good moments we shared", "4. face vs. phase; cap vs. cab", "5. pray, play, murray, cue, Tuesday", "6. beaten, mountain, uh-uh, uh-huh", "7. prism, chasm, little, battle, channel", "8. pretty, daddy, many", "9. eighth, tenth, wealth", "10. most people, best game, grandmaster, desk job", "11. prince vs. prints, tense vs. tents", "12. big game, top post, straight tissue vs. straight issue", "13. kep vs. cap; key vs. kept", "14. life vs. file, leaf vs. feel"]
st = rules.split(".")
sn = st[0]
sn = int(sn)

texts = ["1. Aspiration: repeat, rotation, special, history, happen", "2. Add two more here", "3. I still remember this day and stay grateful for all the good moments we shared", "4. face vs. phase; cap vs. cab", "5. pray, play, murray, cue, Tuesday", "6. beaten, mountain, uh-uh, uh-huh", "7. prism, chasm, little, battle, channel", "8. pretty, daddy, many", "9. eighth, tenth, wealth", "10. most people, best game, grandmaster, desk job", "11. prince vs. prints, tense vs. tents", "12. big game, top post, straight tissue vs. straight issue", "13. kep vs. cap; key vs. kept", "14. life vs. file, leaf vs. feel"]

txt = texts[sn]

print(txt)
etts(txt)
# Out:
# 2. Add two more here
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
